# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
got = pd.read_csv('game_of_thrones_character_deaths.csv')

# %%
plt.title('Mortes em Game of Thrones')

list_death = [['a_game_of_thrones'].sum(),['a_clash_of_kings'].sum(),['a_storm_of_swords'].sum(),['a_feast_for_crows'].sum(),['a_dance_with_dragons'].sum()]

plt.pie(list_death)        
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 3
#       1 plt.title('Mortes em Game of Thrones')
# ----> 3 list_death = [['a_game_of_thrones'].sum(),['a_clash_of_kings'].sum(),['a_storm_of_swords'].sum(),['a_feast_for_crows'].sum(),['a_dance_with_dragons'].sum()]
#       5 plt.pie(list_death)
#       6 plt.legend()
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
plt.title('Mortes em Game of Thrones')

list_death = [['a_game_of_thrones'].sum(),['a_clash_of_kings'].sum(),['a_storm_of_swords'].sum(),['a_feast_for_crows'].sum(),['a_dance_with_dragons'].sum()]

plt.pie(list_death)        
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 3
#       1 plt.title('Mortes em Game of Thrones')
# ----> 3 list_death = [['a_game_of_thrones'].sum(),['a_clash_of_kings'].sum(),['a_storm_of_swords'].sum(),['a_feast_for_crows'].sum(),['a_dance_with_dragons'].sum()]
#       5 plt.pie(list_death)
#       6 plt.legend()
#
# AttributeError: 'list' object has no attribute 'sum'
