# %%
import pandas as pd
import re

# %%
df = pd.read_csv('house.csv')

# %%
filtro1 = df.loc[df['Address'].str.contains('Vida', flags=re.I) & (df['Price'] <=2000000)]
filtro1
# Out:
#            Suburb      Address  Rooms Type      Price Method   SellerG  \
# 3      Aberfeldie   68 Vida St      3    h  1515000.0      S     Barry
# 20912  Aberfeldie   1A Vida St      3    t  1150000.0      S     Barry
# 22415  Aberfeldie  53a Vida St      3    t  1370000.0      S     Barry
# 24747  Aberfeldie   13 Vida St      3    h  1350000.0     VB  McDonald
#
#              Date  Postcode            Regionname  Propertycount  Distance  \
# 3       1/04/2017      3040  Western Metropolitan           1543       7.5
# 20912  11/11/2017      3040  Western Metropolitan           1543       7.5
# 22415  12/08/2017      3040  Western Metropolitan           1543       7.5
# 24747  13/10/2018      3040  Western Metropolitan           1543       7.5
#
#                       CouncilArea
# 3      Moonee Valley City Council
# 20912  Moonee Valley City Council
# 22415  Moonee Valley City Council
# 24747  Moonee Valley City Council
