# %%
import pandas as pd

# %%
df = pd.read_csv('house.csv')

# %%
filtro1 = df.loc[(df['Rooms'] == 5) & (df['Type'] == 't') & (df['Price'] <= 1000000)]
filtro1
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 8458   Balwyn North         23 Oravel St      5    t   950000.0     PI
# 11194       Clayton      3/30 Bettina St      5    t   753500.0      S
# 13202  Balwyn North         23 Oravel St      5    t   950000.0     PI
# 22374     Reservoir  1/128 St Vigeons Rd      5    t   575000.0      S
# 31251  Balwyn North         23 Oravel St      5    t   950000.0     PI
# 35240  Moonee Ponds         18A Fanny St      5    t   980000.0     PI
# 39830       Glenroy        1/217 West St      5    t   645000.0      S
# 46044  Balwyn North         23 Oravel St      5    t   950000.0     PI
# 50707   Maribyrnong        56 Skyline Dr      5    t  1000000.0     PI
# 62265  Balwyn North         23 Oravel St      5    t   950000.0     PI
#
#              SellerG        Date  Postcode                  Regionname  \
# 8458   hockingstuart   6/01/2018      3104       Southern Metropolitan
# ...
